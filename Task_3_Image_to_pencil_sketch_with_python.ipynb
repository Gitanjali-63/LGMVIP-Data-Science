# %% [markdown]
# <a href="https://colab.research.google.com/github/Gitanjali-63/LGMVIP-Data-Science/blob/main/Task_3_Image_to_pencil_sketch_with_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import io
from PIL import Image

# %%
img=cv2.imread("/content/dog.jpg")
img=cv2.resize(img,(500,650))
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=500x650 at 0x7FAEAB317E50>

# %%
gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_img))
# Out:
# <PIL.Image.Image image mode=L size=500x650 at 0x7FAEAB37FD50>

# %%
invert_img=cv2.bitwise_not(gray_img)
display(Image.fromarray(invert_img))
# Out:
# <PIL.Image.Image image mode=L size=500x650 at 0x7FAEAB2F0DD0>

# %%
invert_img=cv2.bitwise_not(gray_img)
display(Image.fromarray(invert_img))
# Out:
# <PIL.Image.Image image mode=L size=500x650 at 0x7FAEAB3F98D0>

# %%
blur=cv2.GaussianBlur(invert_img,(5,5),0,0)
display(Image.fromarray(blur))
# Out:
# <PIL.Image.Image image mode=L size=500x650 at 0x7FAEAB299E50>

# %%
invert_blur=255-blur
pencil_sketch=cv2.divide(gray_img,invert_blur,scale=250.0)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=500x650 at 0x7FAEAB2F8610>

# %%
display(Image.fromarray(img))
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=500x650 at 0x7FAEAB37F590>
# <PIL.Image.Image image mode=L size=500x650 at 0x7FAEAB2F90D0>
